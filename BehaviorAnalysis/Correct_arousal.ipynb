# %%
import os
import scipy.io
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
sns.set_context('paper', font_scale=1.2)
import pandas as pd
import warnings
import sys

warnings.filterwarnings('ignore')
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

# %%
arousal_directory = '/home/sheffieldlab/Desktop/NoReward/DopamineData/Arousal/'
decoder_directory = '/home/sheffieldlab/Desktop/NoReward/DopamineData/Bilateral_withnorew/BayesDecoder/'

# %%
from arousal_correlation import Compile_Arousal as ca

# %% [markdown]
# ### 1979

# %%
data = ca(arousal_directory, decoder_directory, '1979')
data.plot_lapframes(tasks=['Task1', 'Task2', 'Task3'])

# %%
task_dict = {'Task1':0, 'Task2':1, 'Task3':2}
new_corr = data.compile_arousal_corr(task_dict)
laps, error = data.get_lapwiseerror(task_dict)
correction_type = {'Task1': 'remove_firstlap', 'Task2': 'remove_ends', 'Task3': 'remove_ends'}
correct_corr = data.correct_arousal_mat(new_corr, correction_type=correction_type)
data.save_arousal(correct_corr, error)
# Out:
# Corr_size Task1, 24
# Corr_size Task2, 29
# Corr_size Task3, 18
# Decoder_size Task1, 22
# Decoder_size Task2, 26
# Decoder_size Task3, 15
# Corr_size Task1, 22
# Corr_size Task2, 26
# Corr_size Task3, 15

# %% [markdown]
# ## 1980

# %%
data = ca(arousal_directory, decoder_directory, '1980')
data.plot_lapframes(tasks=['Task1', 'Task2', 'Task3'])

# %%
task_dict = {'Task1':0, 'Task2':1, 'Task3':2}
new_corr = data.compile_arousal_corr(task_dict)
laps, error = data.get_lapwiseerror(task_dict)
correction_type = {'Task1': 'remove_ends', 'Task2': 'remove_lastlap', 'Task3': 'remove_firstlap'}
correct_corr = data.correct_arousal_mat(new_corr, correction_type=correction_type)
data.save_arousal(correct_corr, error)
# Out:
# Corr_size Task1, 28
# Corr_size Task2, 17
# Corr_size Task3, 16
# Decoder_size Task1, 25
# Decoder_size Task2, 15
# Decoder_size Task3, 14
# Corr_size Task1, 25
# Corr_size Task2, 15
# Corr_size Task3, 14

# %% [markdown]
# ## 009

# %%
data = ca(arousal_directory, decoder_directory, '009')
data.plot_lapframes(tasks=['Task1', 'Task2', 'Task3'])

# %%
task_dict = {'Task1':0, 'Task2':1, 'Task3':2}
new_corr = data.compile_arousal_corr(task_dict)
laps, error = data.get_lapwiseerror(task_dict)
correction_type = {'Task1': 'remove_ends', 'Task2': 'remove_lastlap', 'Task3': 'remove_ends'}
correct_corr = data.correct_arousal_mat(new_corr, correction_type=correction_type)
data.save_arousal(correct_corr, error)
# Out:
# Corr_size Task1, 30
# Corr_size Task2, 20
# Corr_size Task3, 23
# Decoder_size Task1, 27
# Decoder_size Task2, 18
# Decoder_size Task3, 20
# Corr_size Task1, 27
# Corr_size Task2, 18
# Corr_size Task3, 20

# %% [markdown]
# ## 011

# %%
data = ca(arousal_directory, decoder_directory, '011')
data.plot_lapframes(tasks=['Task1', 'Task2', 'Task3'])

# %%
task_dict = {'Task1':0, 'Task2':1, 'Task3':2}
new_corr = data.compile_arousal_corr(task_dict)
laps, error = data.get_lapwiseerror(task_dict)
correction_type = {'Task1': 'remove_ends', 'Task2': 'donothing', 'Task3': 'remove_first_and_endtwo'}
correct_corr = data.correct_arousal_mat(new_corr, correction_type=correction_type)
data.save_arousal(correct_corr, error)
# Out:
# Corr_size Task1, 56
# Corr_size Task2, 25
# Corr_size Task3, 41
# Decoder_size Task1, 53
# Decoder_size Task2, 24
# Decoder_size Task3, 37
# Corr_size Task1, 53
# Corr_size Task2, 24
# Corr_size Task3, 37

# %% [markdown]
# ## 012

# %%
data = ca(arousal_directory, decoder_directory, '012')
data.plot_lapframes(tasks=['Task1', 'Task2'])

# %%
task_dict = {'Task1':0, 'Task2':1}
new_corr = data.compile_arousal_corr(task_dict)
laps, error = data.get_lapwiseerror(task_dict)
correction_type = {'Task1': 'remove_ends', 'Task2': 'remove_lastlap'}
correct_corr = data.correct_arousal_mat(new_corr, correction_type=correction_type)
data.save_arousal(correct_corr, error)
# Out:
# Corr_size Task1, 43
# Corr_size Task2, 30
# Decoder_size Task1, 40
# Decoder_size Task2, 28
# Corr_size Task1, 40
# Corr_size Task2, 28

# %% [markdown]
# ## 014

# %%
data = ca(arousal_directory, decoder_directory, '014')
data.plot_lapframes(tasks=['Task1', 'Task2', 'Task3'])

# %%
task_dict = {'Task1':0, 'Task2':1, 'Task3':2}
new_corr = data.compile_arousal_corr(task_dict)
laps, error = data.get_lapwiseerror(task_dict)
correction_type = {'Task1': 'remove_ends', 'Task2': 'remove_lastlap', 'Task3': 'remove_firstlap'}
correct_corr = data.correct_arousal_mat(new_corr, correction_type=correction_type)
data.save_arousal(correct_corr, error)
# Out:
# Corr_size Task1, 56
# Corr_size Task2, 47
# Corr_size Task3, 42
# Decoder_size Task1, 53
# Decoder_size Task2, 45
# Decoder_size Task3, 40
# Corr_size Task1, 53
# Corr_size Task2, 45
# Corr_size Task3, 40
