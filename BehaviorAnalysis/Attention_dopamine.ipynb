# %%
import os
import scipy.io
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
sns.set_context('paper', font_scale=1.3)
import pandas as pd
import warnings
import sys

warnings.filterwarnings('ignore')
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
PlottingFormat_Folder = '/Users/seetha/Box Sync/NoReward/Scripts/PlottingTools/'
sys.path.append(PlottingFormat_Folder)
import plottingfunctions as pf

# %%
from define_attentivelaps_dopamine import LoadData

# %%
DirectoryName = '/Users/seetha/Box Sync/NoReward/DopamineData/Bilateral_withnorew/'

# %%
at = LoadData(DirectoryName)
# Out:
# ['012', '014', '1980', '009', '011', '1979']
# {'Task1': '1 Fam Rew', 'Task2': '2 No Rew', 'TaskSal1': '1 Before Saline', 'TaskSal2': '2 After Saline', 'Task5CNO1': '5 Before 5mg', 'Task5CNO2': '6 After 5mg', 'TaskDCZ1': '7 Before DCZ', 'TaskDCZ2': '8 After DCZ'}
# 12.30192642777542
# 012 Task1 41 (41,) (40,)
# (41, 40)
# 0.0
# 012 Task2 29 (29,) (28,)
# (29, 40)
# 0.0
# 012 TaskSal1 37 (37,) (36,)
# (37, 40)
# 0.0
# 012 TaskSal2 68 (68,) (67,)
# (68, 40)
# 0.0
# 012 Task5CNO1 34 (34,) (33,)
# (34, 40)
# 0.0
# 012 Task5CNO2 31 (31,) (30,)
# (31, 40)
# 0.0
# 012 TaskDCZ1 32 (32,) (31,)
# (32, 40)
# 0.0
# 012 TaskDCZ2 45 (45,) (44,)
# (45, 40)
# 0.0
# dict_keys(['Task1', 'Task2', 'TaskSal1', 'TaskSal2', 'Task5CNO1', 'Task5CNO2', 'TaskDCZ1', 'TaskDCZ2'])
# ...

# %% [markdown]
# ## Plot speed heatmap

# %%
fs, ax = plt.subplots(len(at.animalname), 4, figsize=(7, 10), sharex='all')
for n, a in enumerate(at.animalname):
    at.plot_velocity_inspace(fs, ax[n, :], a, taskstoplot=['TaskSal1', 'TaskSal2', 'Task5CNO1', 'Task5CNO2'])
fs.tight_layout()
