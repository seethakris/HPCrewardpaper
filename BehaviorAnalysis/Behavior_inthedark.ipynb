# %%
import os
import scipy.io
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
sns.set_context('paper', font_scale=1.3)
import pandas as pd
import warnings

warnings.filterwarnings('ignore')
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

# %%
from DarkBehavior import GetData

# %%
FolderName = '/home/sheffieldlab/Desktop/NoReward/Dark/'

# %%
gd = GetData(FolderName)
# Out:
# (36, 36)
# (42, 36)
# (58, 36)
# (40, 36)
# (25, 36)
# (25, 36)

# %%
fs, ax = plt.subplots(2, 3, figsize=(10, 6), sharex='all')
ax = ax.flatten()
for n, a in enumerate(gd.animalname):
    gd.plot_velocity_inspace(ax[n], a)
fs.tight_layout()

# %%
speed_ratio = []
for a in gd.animalname:
    speed_ratio.extend(gd.speed_ratio[a])

# %%
sns.distplot(speed_ratio)
