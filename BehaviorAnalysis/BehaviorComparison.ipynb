# %%
import os
import scipy.io
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
sns.set_context('paper', font_scale=1.3)
import pandas as pd
import warnings

warnings.filterwarnings('ignore')
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from CompileBehaviorAcrossAnimals import GetData as gd
task_dict = {'Task1':'1 Fam Rew', 'Task2':'2 No Rew', 'Task3':'3 Fam Rew', 'Task4':'4 Nov Rew'}

# %%
ExperimentFolderName = '/home/sheffieldlab/Desktop/NoReward/ImagingData/Good_behavior/'
ExperimentAnimals = ['NR6', 'NR15','NR14', 'NR21', 'NR23' ]
ControlFolderName = '/home/sheffieldlab/Desktop/NoReward/ControlData/'
ControlAnimals = ['CFC3', 'CFC4']

# %%
A = gd(ExpFolderName=ExperimentFolderName, ControlFolderName=ControlFolderName, 
       ExpAnimals=ExperimentAnimals, ControlAnimals=ControlAnimals, TaskDict=task_dict)
# Out:
# Loading.. CFC3
# Loading.. CFC4
# Loading.. NR6
# Loading.. NR15
# Loading.. NR14
# Loading.. NR21
# Loading.. NR23

# %%
A.plot_numlaps()

# %%
x = A.load_lick_data()
with sns.axes_style('dark'):
    sns.relplot(x='Track(cm)', y='Average Licks Per Lap', col='Task', hue="Animal", estimator=None, lw=2, 
                data=x, kind="line", height=5, aspect=.7)

# %%
fs = plt.figure(dpi=100)
with sns.axes_style('dark'):
    sns.lineplot(x='Track(cm)', y='Average Licks Per Lap', hue="Task", lw=2, 
                data=x[x.Task!='4 Nov Rew'], palette='Dark2')
    plt.title(f'n=%d' % len(Animals))
